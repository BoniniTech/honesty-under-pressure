# %% [markdown]
# # Results — honesty-under-pressure
#
# Charts and tables only. Reads eval logs from `runs/summaries/`; the eval pipeline itself runs headless via `inspect eval`, never from this notebook.
